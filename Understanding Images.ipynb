# %%
import cv2
import matplotlib
from matplotlib import image
from PIL import Image

# %%
img = Image.open("./data/cat.jpg")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=640x427>

# %%
img_mat= matplotlib.image.imread("./data/cat.jpg")

# %%
img_mat
# Out:
# array([[[138, 141, 130],
#         [138, 141, 130],
#         [142, 142, 130],
#         ...,
#         [137, 139, 138],
#         [139, 141, 138],
#         [140, 142, 139]],
#
#        [[137, 139, 128],
#         [138, 140, 129],
#         [140, 140, 128],
#         ...,
#         [137, 139, 138],
#         [138, 140, 137],
#         [139, 141, 138]],
#
#        [[136, 136, 126],
#         [137, 137, 127],
#         [138, 138, 126],
#         ...,
#         [136, 138, 137],
#         [137, 139, 136],
#         [138, 140, 137]],
#
#        ...,
#
#        [[124, 136,  72],
#         [124, 136,  72],
#         [125, 137,  73],
#         ...,
#         [126, 136,  83],
#         [126, 136,  83],
#         [126, 136,  83]],
#
#        [[124, 136,  72],
#         [124, 136,  72],
#         [125, 137,  73],
#         ...,
#         [126, 136,  83],
#         [126, 136,  83],
#         [126, 136,  83]],
#
#        [[124, 136,  72],
#         [124, 136,  72],
#         [125, 137,  73],
# ...

# %%
img_mat.shape
# Out:
# (427, 640, 3)

# %%
img_cv = cv2.imread("./data/cat.jpg")

# %%
img_cv
# Out:
# array([[[130, 141, 138],
#         [130, 141, 138],
#         [130, 142, 142],
#         ...,
#         [138, 139, 137],
#         [138, 141, 139],
#         [139, 142, 140]],
#
#        [[128, 139, 137],
#         [129, 140, 138],
#         [128, 140, 140],
#         ...,
#         [138, 139, 137],
#         [137, 140, 138],
#         [138, 141, 139]],
#
#        [[126, 136, 136],
#         [127, 137, 137],
#         [126, 138, 138],
#         ...,
#         [137, 138, 136],
#         [136, 139, 137],
#         [137, 140, 138]],
#
#        ...,
#
#        [[ 72, 136, 124],
#         [ 72, 136, 124],
#         [ 73, 137, 125],
#         ...,
#         [ 83, 136, 126],
#         [ 83, 136, 126],
#         [ 83, 136, 126]],
#
#        [[ 72, 136, 124],
#         [ 72, 136, 124],
#         [ 73, 137, 125],
#         ...,
#         [ 83, 136, 126],
#         [ 83, 136, 126],
#         [ 83, 136, 126]],
#
#        [[ 72, 136, 124],
#         [ 72, 136, 124],
#         [ 73, 137, 125],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_cv)

# %%
plt.imshow(img_mat)
