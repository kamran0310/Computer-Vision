# %%
import cv2
import matplotlib
import numpy as np

# %%
pwd
# Out:
# 'D:\\AI_App\\FaceRecognition\\Class\\Module-1'

# %%
img_mat = matplotlib.image.imread("./data/parrot.jpg")

# %%
img_mat
# Out:
# array([[[ 72,  63,  48],
#         [ 74,  64,  52],
#         [ 77,  67,  57],
#         ...,
#         [100, 105, 124],
#         [ 93,  99, 115],
#         [ 80,  86, 100]],
#
#        [[ 72,  62,  50],
#         [ 73,  63,  51],
#         [ 75,  65,  55],
#         ...,
#         [208, 211, 226],
#         [ 73,  76,  91],
#         [ 85,  89, 101]],
#
#        [[ 73,  63,  51],
#         [ 72,  62,  50],
#         [ 72,  62,  50],
#         ...,
#         [131, 133, 145],
#         [ 96,  98, 110],
#         [ 91,  93, 105]],
#
#        ...,
#
#        [[ 10,   7,  14],
#         [ 10,   7,  14],
#         [ 10,   7,  14],
#         ...,
#         [ 24,  31,  41],
#         [ 27,  34,  44],
#         [ 25,  32,  42]],
#
#        [[  9,   6,  13],
#         [  9,   6,  13],
#         [  9,   6,  13],
#         ...,
#         [ 10,  19,  28],
#         [ 14,  23,  32],
#         [ 25,  34,  43]],
#
#        [[  7,   6,  12],
#         [  7,   6,  12],
#         [  8,   7,  13],
# ...

# %%
img_cv = cv2.imread("./data/parrot.jpg")

# %%
img_cv
# Out:
# array([[[ 48,  63,  72],
#         [ 52,  64,  74],
#         [ 57,  67,  77],
#         ...,
#         [124, 105, 100],
#         [115,  99,  93],
#         [100,  86,  80]],
#
#        [[ 50,  62,  72],
#         [ 51,  63,  73],
#         [ 55,  65,  75],
#         ...,
#         [226, 211, 208],
#         [ 91,  76,  73],
#         [101,  89,  85]],
#
#        [[ 51,  63,  73],
#         [ 50,  62,  72],
#         [ 50,  62,  72],
#         ...,
#         [145, 133, 131],
#         [110,  98,  96],
#         [105,  93,  91]],
#
#        ...,
#
#        [[ 14,   7,  10],
#         [ 14,   7,  10],
#         [ 14,   7,  10],
#         ...,
#         [ 41,  31,  24],
#         [ 44,  34,  27],
#         [ 42,  32,  25]],
#
#        [[ 13,   6,   9],
#         [ 13,   6,   9],
#         [ 13,   6,   9],
#         ...,
#         [ 28,  19,  10],
#         [ 32,  23,  14],
#         [ 43,  34,  25]],
#
#        [[ 12,   6,   7],
#         [ 12,   6,   7],
#         [ 13,   7,   8],
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.imshow(img_mat) #read image in RGB format

# %%
plt.imshow(cv2.imread("./data/parrot.jpg")) #read image in BGR format

# %%
img_mat.shape
# Out:
# (360, 540, 3)

# %%
img_cv.shape
# Out:
# (360, 540, 3)

# %%
type(img_mat)
# Out:
# numpy.ndarray

# %%
r = img_mat[:,:,0] #red matrix only
g = img_mat[:,:,1] #blue matrix only
b = img_mat[:,:,2] #green matrix only

# %%
r.shape, g.shape, b.shape
# Out:
# ((360, 540), (360, 540), (360, 540))

# %%
plt.imshow(r, cmap='gray')

# %%
plt.imshow(g, cmap='gray')

# %%
plt.imshow(b, cmap='gray')

# %%
plt.figure(figsize=(20,6))
plt.subplot(1,4,1)
plt.title('Red Region')
plt.imshow(r, cmap='gray')
plt.subplot(1,4,2)
plt.title('Blue Region')
plt.imshow(g, cmap='gray')
plt.subplot(1,4,3)
plt.title('Green Region')
plt.imshow(b, cmap='gray')
plt.subplot(1,4,4)
plt.title('Full Region')
plt.imshow(img_mat)
plt.show()

# %%
gray_mat = cv2.cvtColor(img_mat, cv2.COLOR_RGB2GRAY)
gray_cv = cv2.cvtColor(img_mat, cv2.COLOR_BGR2GRAY)

# %%
plt.figure(figsize=(2,2))
plt.imshow(gray_mat, cmap='gray')

# %%
plt.figure(figsize=(2,2))
plt.imshow(gray_cv, cmap='gray')

# %%
gray_cv.shape, gray_mat.shape
# Out:
# ((360, 540), (360, 540))
